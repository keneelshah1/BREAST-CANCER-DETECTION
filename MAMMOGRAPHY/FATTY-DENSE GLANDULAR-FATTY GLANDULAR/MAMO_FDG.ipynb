pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb252.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb253.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb254.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb255.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb256.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb257.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb258.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb259.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb260.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb261.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb262.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb263.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb264.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb265.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb266.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb267.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb268.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb269.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb270.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb271.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb272.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb273.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb274.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb275.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb276.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb277.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb278.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb279.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb280.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb281.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb282.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb283.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb284.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb285.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb286.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb287.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb288.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb289.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb290.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb291.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb292.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb293.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb294.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb295.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb296.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb297.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb298.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb299.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb300.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb301.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb302.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb303.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb304.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb305.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb306.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb307.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb308.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb309.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb310.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb311.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb312.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb313.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb314.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb315.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb316.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb317.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb318.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb319.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb320.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb321.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb322.pgm
# C:\Users\admin\Desktop\New folder\dataset\all-mias\README
# Requirement already satisfied: Livelossplot in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (0.5.4)
# Requirement already satisfied: bokeh in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from Livelossplot) (2.3.0)
# Requirement already satisfied: matplotlib in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from Livelossplot) (3.3.2)
# Requirement already satisfied: ipython in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from Livelossplot) (7.20.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (2.8.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (3.7.4.3)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (2.11.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (6.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (20.9)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from bokeh->Livelossplot) (8.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from Jinja2>=2.7->bokeh->Livelossplot) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from packaging>=16.8->bokeh->Livelossplot) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from python-dateutil>=2.1->bokeh->Livelossplot) (1.15.0)
# Requirement already satisfied: backcall in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (3.0.8)
# Requirement already satisfied: pickleshare in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (0.7.5)
# Requirement already satisfied: pygments in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (2.7.4)
# Requirement already satisfied: traitlets>=4.2 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (52.0.0.post20210125)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (0.17.1)
# Requirement already satisfied: colorama in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (0.4.4)
# Requirement already satisfied: decorator in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from ipython->Livelossplot) (4.4.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from jedi>=0.16->ipython->Livelossplot) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->Livelossplot) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from traitlets>=4.2->ipython->Livelossplot) (0.2.0)
# Requirement already satisfied: certifi>=2020.06.20 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from matplotlib->Livelossplot) (2020.12.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from matplotlib->Livelossplot) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\.conda\envs\tensorflow\lib\site-packages (from matplotlib->Livelossplot) (0.10.0)

# %%
import numpy as np
import pandas as pd
import cv2
from PIL import Image
import scipy

import tensorflow as tf
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.utils import *
# import pydot

from sklearn.metrics import *
from sklearn.model_selection import *
import tensorflow.keras.backend as K

from tqdm import tqdm, tqdm_notebook
from colorama import Fore
import json
import matplotlib.pyplot as plt
import seaborn as sns
from glob import glob
from skimage.io import *
# %config Completer.use_jedi = False
import time
from sklearn.decomposition import PCA
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import lightgbm as lgb
# import xgboost as xgb

print("All modules have been imported")
# Out:
# All modules have been imported

# %%
info=pd.read_csv(r'C:\Users\admin\Desktop\New folder\dataset\Info.txt',sep=" ")
info=info.drop('Unnamed: 7',axis=1)
info.SEVERITY.fillna(0)
# Out:
# 0      B
# 1      B
# 2      0
# 3      0
# 4      B
#       ..
# 325    0
# 326    0
# 327    0
# 328    0
# 329    0
# Name: SEVERITY, Length: 330, dtype: object

# %%
sns.set_style('darkgrid')
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15,5))
sns.barplot(x=info.BG.unique(),y=info.BG.value_counts(),palette='Blues_r',ax=ax1)
sns.barplot(x=info.CLASS.unique(),y=info.CLASS.value_counts(),palette='Blues_r',ax=ax2)
# Out:
# <AxesSubplot:ylabel='CLASS'>

# %%
from PIL import Image
import glob
x= []
for filename in sorted(glob.glob(r"C:\Users\admin\Desktop\New folder\dataset\all-mias\*.pgm")): 
    img=cv2.imread(filename)
    img =cv2.resize(img,(224, 224))
    x.append(img)
fig=plt.figure(figsize=(15,15))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = np.random.randint(10)
    fig.add_subplot(rows, columns, i)
    plt.imshow(x[i])
plt.show()

# %%
# Image Augmentation
no_angles = 360
url = r"C:/Users/admin/Desktop/New folder/dataset/all-mias/"

def save_dictionary(path,data):
        print('saving catalog...')
        #open('u.item', encoding="utf-8")
        import json
        with open(path,'w') as outfile:
            json.dump(str(data), fp=outfile)
        # save to file:
        print(' catalog saved')

# %%
def read_image():
        print("Reading images")
        import cv2
        info = {}
        for i in range(322):
            if i<9:
                image_name='mdb00'+str(i+1)
            elif i<99:
                image_name='mdb0'+str(i+1)
            else:
                image_name = 'mdb' + str(i+1)
            image_address= url+image_name+'.pgm'
            img = cv2.imread(image_address,1)
            img = cv2.resize(img, (224,224))
            rows, cols,channel = img.shape
            info[image_name]={}
            for angle in range(0,no_angles,8):
                M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1) 
                img_rotated = cv2.warpAffine(img, M, (cols, rows))
                info[image_name][angle]=img_rotated
        return (info)

# %%
import os #Operating System
import sys #System
# train_generator = train_datagen.flow(x_train, y_train, batch_size =)
# val_generator = val_datagen.flow(x_val, y_val, batch_size = 64)
# test_generator=test_datagen.flow(x_test,y_test,batch_size = 64)

def get_script_path():
    return os.path.dirname(os.path.realpath(sys.argv[0]))    

def read_lable():
    filename = url+'Info.txt'
    text_all = open(filename).read()
    #print(text_all)
    lines=text_all.split('\n')
    info={}
    for line in lines:
        words=line.split(' ')
        if len(words)>1:
            if (words[1] == 'G'):
                info[words[0]] = {}
                for angle in range(no_angles):
                    info[words[0]][angle] = 2
            if (words[1] == 'D'):
                info[words[0]] = {}
                for  angle in range(no_angles):
                    info[words[0]][angle] = 1
            if (words[1] == 'F'):
                info[words[0]] = {}
                for  angle in range(no_angles):
                    info[words[0]][angle] = 0
            
    return (info)

# %%
import numpy as np
lable_info=read_lable()
image_info=read_image()
ids=lable_info.keys() 
#del lable_info['Truth-Data:']
X=[]
Y=[]
for id in ids:
    for angle in range(0,no_angles,8):
        X.append(image_info[id][angle])
        Y.append(lable_info[id][angle])
X=np.array(X)
Y=np.array(Y)
Y=to_categorical(Y,3)
x_train, x_test1, y_train, y_test1 = train_test_split(X, Y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test1, y_test1, test_size=0.3, random_state=42)
print(len(x_train),len(x_val),len(x_test))
# Out:
# Reading images
# 10143 3042 1305

# %%
#Callbacks
c2=tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=6,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

c3=tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=6,
    mode="auto",
    min_delta=0.0001,
    cooldown=0,
    min_lr=0.001
)
nClasses=3

# %%
base_Neural_Net= VGG19(input_shape=(224,224,3), weights='imagenet', include_top=False)
model=Sequential()
model.add(base_Neural_Net)
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(256,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(3,activation='softmax'))

for layer in base_Neural_Net.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 14s 0us/step

# %%
c1=PlotLossesKeras()
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy','AUC'])
history=model.fit(x_train,y_train,epochs=10,callbacks=[c1,c3],batch_size=16)
# Out:
# accuracy
# 	accuracy         	 (min:    0.718, max:    0.970, cur:    0.970)
# auc
# 	auc              	 (min:    0.883, max:    0.997, cur:    0.997)
# Loss
# 	loss             	 (min:    0.085, max:    0.675, cur:    0.085)
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_loss` which is not available. Available metrics are: loss,accuracy,auc,lr
# 634/634 [==============================] - 1798s 3s/step - loss: 0.0855 - accuracy: 0.9698 - auc: 0.9974

# %%
model.evaluate(x_val,y_val,callbacks=[c2,c3],batch_size=16)
# Out:
# 191/191 [==============================] - 855s 4s/step - loss: 0.1990 - accuracy: 0.9366 - auc: 0.9889
# [0.19898653030395508, 0.9365549087524414, 0.9889170527458191]

# %%
print("Performance Report:")
y_pred8=model.predict_classes(x_test)
y_test8=[np.argmax(x) for x in y_test]
y_pred_prb8=model.predict_proba(x_test)
target=["G","F","D"]
from sklearn import metrics
print('Accuracy score is :', np.round(metrics.accuracy_score(y_test8, y_pred8),4))
print('Precision score is :', np.round(metrics.precision_score(y_test8, y_pred8, average='weighted'),4))
print('Recall score is :', np.round(metrics.recall_score(y_test8,y_pred8, average='weighted'),4))
print('F1 Score is :', np.round(metrics.f1_score(y_test8, y_pred8, average='weighted'),4))
print('ROC AUC Score is :', np.round(metrics.roc_auc_score(y_test8, y_pred_prb8,multi_class='ovo', average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test8, y_pred8),4))
print('\t\tClassification Report:\n', metrics.classification_report(y_test8, y_pred8,target_names=target))
# Out:
# Performance Report:
# WARNING:tensorflow:From <ipython-input-26-3a7c5168d09b>:2: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# WARNING:tensorflow:From <ipython-input-26-3a7c5168d09b>:4: Sequential.predict_proba (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use `model.predict()` instead.
# Accuracy score is : 0.9425
# Precision score is : 0.9431
# Recall score is : 0.9425
# F1 Score is : 0.9427
# ROC AUC Score is : 0.9908
# Cohen Kappa Score: 0.9135
# 		Classification Report:
#                precision    recall  f1-score   support
#
#            G       0.96      0.94      0.95       392
#            F       0.96      0.95      0.95       461
#            D       0.91      0.94      0.93       452
#
#     accuracy                           0.94      1305
#    macro avg       0.94      0.94      0.94      1305
# weighted avg       0.94      0.94      0.94      1305

# %%
model.save("MAMO_BCD.h5")

# %%
from tensorflow.keras.preprocessing import image
models=load_model("MAMO_BCD.h5")

# %%
def predictor(filename) :
    test_image = filename
    image_result = Image.open(test_image)
    # test_image = image.load_img(test_image, target_size=(100,100))
    test_image = image.load_img(test_image, target_size=(224,224,3))
    test_image = image.img_to_array(test_image)
#     test_image = test_image/255
    test_image = np.expand_dims(test_image, axis=0)
    result = models.predict(test_image)
    r = np.max(result)
    per = r*100
    percentage = round(per,4)
    categories = ['F','D','G']
    image_result = plt.imshow(image_result)
    output = categories[np.argmax(result)]
    return result,percentage,output


CANCER_DETECTOR = predictor(r'C:\Users\admin\Desktop\New folder\dataset\all-mias\mdb136.pgm')
print(CANCER_DETECTOR)
# Out:
# (array([[5.1152122e-01, 4.8847717e-01, 1.6080101e-06]], dtype=float32), 51.1521, 'F')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25088)             100352
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 26,549,315
# Trainable params: 6,474,243
# Non-trainable params: 20,075,072
# _________________________________________________________________
